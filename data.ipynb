# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanket321321/4sem.....php/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints =np.array([0,6])
ypoints =np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,10,1])
plt.plot(ypoints,marker='o')
plt.show()
plt.plot(ypoints,marker='*')
plt.title('smple line chart')
plt.show()

# %%
plt.plot(ypoints,marker='o',ms=20)
plt.show()

# %%
plt.plot(ypoints,marker='o',ms=20,mec='r')
plt.show()

# %%
plt.plot(ypoints,marker='o',ms=20,mec='r',mfc='g')
plt.show()
plt.title('smple line chart')
plt.show()

# %%
plt.bar([1,2,3,4],[10,15,7,12],color='green',label='example data')
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.title('customized bar chart')
plt.legend()
plt.show()

# %%
plt.title('smple line chart')
plt.show()

# %%
import pandas as pd
import matploatlib.pyplo                                                                                   t as plt
connection =xyz.connect('database.xyz')
Cursor=connection.Cursor()
cursor

# %%
student_id=list([1,2,3,4,5,6])
student_subject=list(["a","b","c","d","e","f"])
score=list([50,60,70,80,90,10])
import pandas as pd
d={"student_id":student_id,"student_subject":student_subject,"score":score}
df=pd.DataFrame(d)
df
# Out:
#    student_id student_subject  score
# 0           1               a     50
# 1           2               b     60
# 2           3               c     70
# 3           4               d     80
# 4           5               e     90
# 5           6               f     10

# %%
from google.colab import  files
import pandas as pd
data=files.upload()
# Out:
#      <input type="file" id="files-e2cd3e72-02bd-46d0-b738-7a107267b81f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2cd3e72-02bd-46d0-b738-7a107267b81f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("abc.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
x=df.iloc[:,3]
y=df.iloc[:,5]
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.stem(x,y)
plt.show()

# %%
plt.stackplot(x,y)

plt.show()

# %%
plt.step(x,y)
plt.show()

# %%
plt.hist(x)
plt.show()
